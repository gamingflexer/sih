# %%
from googletrans import Translator
translator = Translator()
import pandas as pd

# %%
data = pd.read_json('x.json',lines = True)

# %%
data.head(3)
# Out:
#                     id      conversation_id                created_at  \
# 0  1499042405357662217  1499021225984626688 2022-03-02 20:52:14+05:30
# 1  1499041564345389058  1499041564345389056 2022-03-02 20:48:54+05:30
# 2  1499041078732890117  1499041073796194304 2022-03-02 20:46:58+05:30
#
#         date      time  timezone              user_id         username  \
# 0 2022-03-02  20:52:14       530   966104930724601856        paulsgkim
# 1 2022-03-02  20:48:54       530           3181865462  floodcoiqkdaluy
# 2 2022-03-02  20:46:58       530  1019974187975430144      extinctionr
#
#                    name place  ... geo source user_rt_id user_rt retweet_id  \
# 0          paul kim 김석인        ...
# 1       ニュースの番人🇯🇵⛴☘️🙊🌸🌎        ...
# 2  Extinction Rebellion        ...
#
#                                             reply_to  retweet_date  translate  \
# 0  [{'screen_name': 'kemc', 'name': 'Kathleen McL...
# 1                                                 []
# ...

# %%
data.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
#auto increment id
data=data.drop(columns=['user_id','conversation_id','id','place','thumbnail','translate','trans_src','trans_dest'])
data.columns
# Out:
# Index(['created_at', 'date', 'time', 'timezone', 'username', 'name', 'tweet',
#        'language', 'mentions', 'urls', 'photos', 'replies_count',
#        'retweets_count', 'likes_count', 'hashtags', 'cashtags', 'link',
#        'retweet', 'quote_url', 'video', 'near', 'geo', 'source', 'user_rt_id',
#        'user_rt', 'retweet_id', 'reply_to', 'retweet_date'],
#       dtype='object')

# %%
#id unqiue - may assign one
#con_id unique 
#created at - converge maybe
#date - scrapped date
#time - created
#user_id
#username
#name - clean
#place - drop
#tweet - translate
#lan - many
#mentions
#urls
#phtots
#replies count,retweets_count,likes_count  ---- can be used to rank
#hashtags - maybe be used further
#link - tweet link ----can be displayed
#retweet
#quote_url
#video
#near?
#geo - imp
#source?
#user_rt_id
#user_rt ----can be used by model - new categriws
#retweet_id,reply_to,retweet_date

# %%
data['tweet'].head(3)
# Out:
# 0     the rise of gianforte entirely tracks w the d...
# 1                                          youtuber 2
# 2    this shows the terrifying extent of the wilson...
# Name: tweet, dtype: object

# %%
data['translated'].head(3)
# Out:
# 0    @kemc the rise of gianforte entirely tracks w ...
# 1    うそか本当か未確認なのだが以下の情報を共有する。  YouTuberの改憲君の動画から、ロシ...
# 2    This shows the terrifying extent of the Wilson...
# Name: translated, dtype: object

# %%
import re
def pre_process1_rsw1(text):
    text = "".join(text.split('\n'))  # remove whitespaces
    text = text.lower()

    # using re
    text = re.sub('http\S+\s*', ' ', text)
    text = re.sub('RT|cc', ' ', text)
    text = re.sub('#\S+', ' ', text)
    text = re.sub('@\S+', ' ', text)

    # for i in range (len(emails)): #removes emails
    #   text = text.replace(emails[i],"")

    text = re.sub(r'(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4})', '', text)  # removes phone numbers
    text = re.sub(r'[^\x00-\x7f]', ' ', text)
    text = re.sub('\s+', ' ', text)
    text = re.sub("\n", " ", text)

    return ''.join(text)

data["tweet"] = data["tweet"].apply(pre_process1_rsw1)

# %%
tweets= []
t_tweets = []
translations = {}

for i in range (len(data["tweet"])):
    tweets = tweets + [data["tweet"][i]]

for element in tweets:
    # add translation to the dictionary
    try:
        t_tweets = t_tweets + [str(translator.translate(element,des= "en"))]
    except AttributeError:
        t_tweets = t_tweets + [element]
print(translations)
# Out:
# {}

# %%
t_tweets
# Out:
# [" the rise of gianforte entirely tracks w the decline of the 'ethical hunter'. the trope of the 'conservation-minded hunter' gets a ton of life in mt discourse but with the flood of newcomers seeking a bastion of white colonial fantasy, hunting for bloodsport is the new norm",
#  ' youtuber 2 ',
#  'this shows the terrifying extent of the wilsons river flood. ',
#  "hey australia! more coal = more floods. it's time to rebel against the fossil fuel industry destroying our lives! ",
#  'it started with stopping kremlin-backed media outlets from buying ads. within days, it s turned into a flood of restrictions. the russian invasion of ukraine has forced social media giants to do something they once considered unthinkable: pick a side. ',
#  ' of course !!!! i won t ever complain about heat ',
#  ' thank you jess ',
#  ' you too gary !!!!!!',
#  ' thank you phoenix !!! unfortunately i have some work to do before i can get out .we are busy !!!! ',
# ...

# %%
for
# Out:
# "@kemc the rise of gianforte entirely tracks w the decline of the 'ethical hunter'. the trope of the 'conservation-minded hunter' gets a ton of life in mt discourse but with the flood of newcomers seeking a bastion of white colonial fantasy, hunting for bloodsport is the new norm"

# %%
data['translate'].unique()
# Out:
# array([''], dtype=object)
